# %%
import pandas as pd
import numpy as np

# %%
import os
import csv

from google.colab import drive
drive.mount('/content/drive')

#os.lis`enter code here`tdir(file_path)
def myfunction(data):
  print(data)
file_path = "/content/drive/MyDrive/BrixSpectra"

b = []

df = pd.read_csv("/content/drive/MyDrive/BrixSpectra/NZRedp3.csv")
column_name = list(df.columns)
column_name.append("file_name")


for file in os.listdir(file_path):
  if file.endswith(".csv"):
    file2 = file_path + "/" + str(file)
    df1 = pd.read_csv(file2)
    reading = []
    for col in df1.columns:
      a = df1[col].mean()
      reading.append(a)
    reading.append(str(file)[:-4])
  b.append(reading)

with open('students.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(column_name)
     for i in b:
       writer.writerow(i)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df3 = pd.read_csv("students.csv")
df3
# Out:
#          410 nm       435 nm       460 nm      485 nm       510 nm  \
# 0   2717.466154   956.668462  1926.724615  579.996923   976.415385
# 1    458.138000   152.981333   234.204000   93.522667   120.145333
# 2    953.168421   214.602632   305.863158  111.856316   161.476316
# 3    798.732778   343.097778   686.890000  250.050000   404.189444
# 4   2622.231053   874.413158  1716.985263  615.893158  1250.464737
# 5    639.467500   238.280000   406.734500  156.557500   217.118500
# 6    953.676667   274.622083   439.748333  121.188750   186.718333
# 7   1108.886667   352.882222   562.690556  193.076667   269.800000
# 8   1661.567059   510.787647  1058.827647  413.073529  1159.337647
# 9   2869.723571  1051.551429  2176.048571  795.558571  1385.790714
# 10  2441.702857   862.547857  1818.967143  399.600714   676.127857
# 11  1519.714783   381.831739   400.717826  125.210000   171.753478
# 12  1614.903684   628.327368  1241.089474  329.827895   464.439474
# ...

# %%
def myfunction(data):
  print(data)
file_path = "/content/drive/MyDrive/AppleSfiles"

b = []

df = pd.read_csv("/content/drive/MyDrive/AppleSfiles/IgetApple2_p2rt.csv",skiprows=[1])
column_name = list(df.columns)
column_name.append("file_name")


for file in os.listdir(file_path):
  if file.endswith(".csv"):
    file2 = file_path + "/" + str(file)
    df1 = pd.read_csv(file2,skiprows=[1],index_col=False)
    reading = []
    for col in df1.columns:
      a = np.nanmean(df1[col])
      reading.append(a)
    reading.append(str(file)[:-4])
  b.append(reading)

with open('students2.csv', 'w', newline='') as file:
     writer = csv.writer(file)
     writer.writerow(column_name)
     for i in b:
       writer.writerow(i)

# %%
df4= pd.read_csv("students2.csv")
df4
# Out:
#           410 nm      435 nm       460 nm      485 nm      510 nm      535 nm  \
# 0     676.608421  168.404211   348.614737   68.422105  146.051053  531.995789
# 1     656.019474  160.404737   555.131579  110.870000  298.440000  613.002105
# 2    1303.259474  211.753684   325.685263   78.071053  148.190000  459.234211
# 3     526.226316  147.110000   330.107368  123.998947  232.865263  424.068947
# 4    1074.893684  305.582105   720.207895  218.302105  403.146842  724.028421
# ..           ...         ...          ...         ...         ...         ...
# 261   646.355263  186.790000   718.071579  129.640000  337.124211  580.240000
# 262   905.856842  270.331579  1115.557368  190.725789  432.703158  869.700526
# 263   633.373684  163.206316   449.858947  128.937368  251.040000  482.047368
# 264   537.574737  176.150000   484.590000  122.490000  223.540000  422.153158
# 265   446.438421  165.193684   486.052632  127.860000  242.196842  453.763158
#
# ...

# %%
dffinal = pd.concat(map(pd.read_csv, ['students.csv', 'students2.csv']),ignore_index=True)
dffinal
# Out:
#           410 nm      435 nm       460 nm      485 nm       510 nm  \
# 0    2717.466154  956.668462  1926.724615  579.996923   976.415385
# 1     458.138000  152.981333   234.204000   93.522667   120.145333
# 2     953.168421  214.602632   305.863158  111.856316   161.476316
# 3     798.732778  343.097778   686.890000  250.050000   404.189444
# 4    2622.231053  874.413158  1716.985263  615.893158  1250.464737
# ..           ...         ...          ...         ...          ...
# 307   646.355263  186.790000   718.071579  129.640000   337.124211
# 308   905.856842  270.331579  1115.557368  190.725789   432.703158
# 309   633.373684  163.206316   449.858947  128.937368   251.040000
# 310   537.574737  176.150000   484.590000  122.490000   223.540000
# 311   446.438421  165.193684   486.052632  127.860000   242.196842
#
#           535 nm      560 nm      585 nm       610 nm      645 nm  \
# 0    1632.929231  197.940769  326.194615  4609.105385  394.927692
# ...

# %%
b1 = []
df6 = pd.read_csv("/content/drive/MyDrive/WhiteD1.csv")
for i in df6.columns:
  a1 = df6[i].mean()
  b1.append(a1)

# %%
b1
# Out:
# [10520.600400000001,
#  6071.2976,
#  8504.2672,
#  3792.4179999999997,
#  3713.5780000000004,
#  4351.244,
#  829.4496,
#  800.3844,
#  5811.1708,
#  481.2528,
#  1304.4764000000002,
#  159.9488,
#  413.008,
#  313.5472,
#  1307.9188000000001,
#  2181.7252000000003,
#  642.4584,
#  310.8792]

# %%
import math
n = 0
for i in df.columns:
  for j in range(0,312):
    dffinal.loc[j,i] = -math.log(dffinal[i][j]/b1[n])
  n += 1

# %%
ref = pd.read_excel("/content/drive/MyDrive/BrixVal (1).xlsx")
ref
# Out:
#                File Brix value
# 0        Applep1_27       13.5
# 1        Applep2_27       12.9
# 2        Applep3_27       12.8
# 3        Applep4_27       12.9
# 4        RedApplep1       14.7
# ..              ...        ...
# 311   WTkag_3001_p4       18.2
# 312  NWTkag_3001_p1       13.7
# 313  NWTkag_3001_p2       14.5
# 314  NWTkag_3001_p3       14.4
# 315  NWTkag_3001_p4       15.3
#
# [316 rows x 2 columns]

# %%
for i in range(0,312):
  for j in range(0,316):
    if dffinal['file_name'][i] == ref['File'][j]:
      dffinal.loc[i,'new'] = ref['Brix value'][j]

# %%
dffinal
# Out:
#        410 nm    435 nm    460 nm    485 nm    510 nm    535 nm    560 nm  \
# 0    1.353635  1.847871  1.484747  1.877736  1.335863  0.980086  1.432795
# 1    3.133920  3.681012  3.592131  3.702555  3.431049  3.398641  3.110151
# 2    2.401299  3.342540  3.325186  3.523544  3.135393  2.794936  3.106394
# 3    2.578064  2.873312  2.516149  2.719098  2.217867  1.935595  1.977503
# 4    1.389310  1.937775  1.599998  1.817686  1.088481  0.680206  0.960676
# ..        ...       ...       ...       ...       ...       ...       ...
# 307  2.789741  3.481343  2.471754  3.375998  2.399300  2.014775  2.519958
# 308  2.452209  3.111678  2.031214  2.989922  2.149699  1.610068  2.172865
# 309  2.810030  3.616312  2.939389  3.381432  2.694139  2.200175  2.549611
# 310  2.974023  3.539992  2.865020  3.432730  2.810161  2.332849  2.245485
# 311  3.159789  3.604209  2.862006  3.389823  2.730000  2.260642  2.312222
#
#        585 nm    610 nm    645 nm    680 nm    705 nm    730 nm    760 nm  \
# ...

# %%
dffinal.isnull().sum(axis = 0)
# Out:
# 410 nm       0
# 435 nm       0
# 460 nm       0
# 485 nm       0
# 510 nm       0
# 535 nm       0
# 560 nm       0
# 585 nm       0
# 610 nm       0
# 645 nm       0
# 680 nm       0
# 705 nm       0
# 730 nm       0
# 760 nm       0
# 810 nm       0
# 860 nm       0
# 900 nm       0
# 940 nm       0
# file_name    0
# new          2
# dtype: int64

# %%
for i in range(0,312):
  if pd.isna(dffinal['new'][i]) :
    print(dffinal['file_name'][i])
# Out:
# IndApple2_p3
# Kashmir1_2301_p1

# %%
dffinal.to_csv('file_name.csv', index=False)

# %%
df12 = dffinal.dropna(axis=0, subset=['new'])
df12 = df12[(df12.new != '*' )]
df12 = df12[(df12.new != '-' )]
df12
# Out:
#        410 nm    435 nm    460 nm    485 nm    510 nm    535 nm    560 nm  \
# 0    1.353635  1.847871  1.484747  1.877736  1.335863  0.980086  1.432795
# 1    3.133920  3.681012  3.592131  3.702555  3.431049  3.398641  3.110151
# 2    2.401299  3.342540  3.325186  3.523544  3.135393  2.794936  3.106394
# 3    2.578064  2.873312  2.516149  2.719098  2.217867  1.935595  1.977503
# 4    1.389310  1.937775  1.599998  1.817686  1.088481  0.680206  0.960676
# ..        ...       ...       ...       ...       ...       ...       ...
# 307  2.789741  3.481343  2.471754  3.375998  2.399300  2.014775  2.519958
# 308  2.452209  3.111678  2.031214  2.989922  2.149699  1.610068  2.172865
# 309  2.810030  3.616312  2.939389  3.381432  2.694139  2.200175  2.549611
# 310  2.974023  3.539992  2.865020  3.432730  2.810161  2.332849  2.245485
# 311  3.159789  3.604209  2.862006  3.389823  2.730000  2.260642  2.312222
#
#        585 nm    610 nm    645 nm    680 nm    705 nm    730 nm    760 nm  \
# ...

# %%
y = df12['new']
x = df12.drop(['file_name','new'], axis=1)
x
# Out:
#        410 nm    435 nm    460 nm    485 nm    510 nm    535 nm    560 nm  \
# 0    1.353635  1.847871  1.484747  1.877736  1.335863  0.980086  1.432795
# 1    3.133920  3.681012  3.592131  3.702555  3.431049  3.398641  3.110151
# 2    2.401299  3.342540  3.325186  3.523544  3.135393  2.794936  3.106394
# 3    2.578064  2.873312  2.516149  2.719098  2.217867  1.935595  1.977503
# 4    1.389310  1.937775  1.599998  1.817686  1.088481  0.680206  0.960676
# ..        ...       ...       ...       ...       ...       ...       ...
# 307  2.789741  3.481343  2.471754  3.375998  2.399300  2.014775  2.519958
# 308  2.452209  3.111678  2.031214  2.989922  2.149699  1.610068  2.172865
# 309  2.810030  3.616312  2.939389  3.381432  2.694139  2.200175  2.549611
# 310  2.974023  3.539992  2.865020  3.432730  2.810161  2.332849  2.245485
# 311  3.159789  3.604209  2.862006  3.389823  2.730000  2.260642  2.312222
#
#        585 nm    610 nm    645 nm    680 nm    705 nm    730 nm    760 nm  \
# ...

# %%
#Splitting the data into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1, random_state=0)

# %%
#Applying Ols model
import pandas as pd
import numpy as np
import statsmodels.api as sm
#adding constant term
x_train = sm.add_constant(x_train)
#FFitting model
model = sm.OLS(y_train.astype(float), x_train.astype(float)).fit()
summary =model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    new   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     10.30
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):           1.18e-21
# Time:                        08:59:17   Log-Likelihood:                -528.49
# No. Observations:                 277   AIC:                             1095.
# Df Residuals:                     258   BIC:                             1164.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.8456      1.384      7.113      0.000       7.120      12.572
# ...

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()

lin.fit(x, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(x)

poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
y_pred = lin2.fit(x_train, y_train).predict(x_test)
print(lin2.score(x_train, y_train))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - const
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-af09e7af3891> in <module>
# ----> 1 y_pred = lin2.fit(x_train, y_train).predict(x_test)
#       2 print(lin2.score(x_train, y_train))
#
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
# ...

# %%
x_test = sm.add_constant(x_test)
y_pred = model.predict(x_test.astype(float))
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
#Estimating Pearson R coefficient
from scipy.stats import pearsonr
corr, _ = pearsonr(y_test, y_pred)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.541

# %%
pip install pyserial
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import serial

# %%
import serial.tools.list_ports
print(list(serial.tools.list_ports.comports()))
# Out:
# []

# %%
ser = serial.Serial(port='COM5', baudrate=115200)

print("connected to: " + ser.portstr)
count=0

while count < 20:
    for line in ser.readline():

        print(str(count) + str(': ') + chr(line) )
        count = count+1
        with open('students3.csv', 'w', newline='') as file:
          writer = csv.writer(file)
          writer.writerow(line)
        count = count+1

ser.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/serial/serialposix.py in open(self)
#     321         try:
# --> 322             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COM5'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-50-7c57568ae090> in <module>
# ----> 1 ser = serial.Serial(port='COM5', baudrate=115200)
#       2
#       3 print("connected to: " + ser.portstr)
#       4 count=0
#       5
#
# ...
